# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("cAMP.csv",sep="\t")

# %%
data["Plate"].value_counts()
# Out:
# Plate         1229
# 2             1080
# A              410
# F              410
# Background     410
# G              410
# E              410
# C              410
# H              410
# B              410
# D              410
# Results        410
# 1              150
# Assay            6
# Protocol         4
# Instrument       2
# Basic            1
# Labels:          1
# User             1
# Label            1
# Serial#:         1
# Exported         1
# Name: Plate, dtype: int64

# %%
#row indices of "background" in "Plate"
background_ind=np.where(data["Plate"]=="Background")
#add 2 for plate number
background_ind=np.array([x+2 for x in background_ind])
background_ind=background_ind.tolist()
background_ind=background_ind[0]

# %%
data["Plate"].iloc[background_ind].value_counts()
# Out:
# 2    360
# 1     50
# Name: Plate, dtype: int64

# %%
data["end"]
# Out:
# 0         0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8        12
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      end
# 20        0
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28       12
# 29      NaN
#        ...
# 8203    NaN
# 8204    NaN
# 8205    NaN
# 8206    NaN
# 8207    NaN
# 8208    NaN
# 8209    NaN
# 8210    NaN
# 8211    NaN
# 8212    NaN
# 8213    NaN
# 8214    NaN
# 8215    NaN
# 8216    NaN
# 8217    NaN
# 8218    NaN
# 8219    NaN
# 8220    NaN
# 8221    NaN
# 8222    NaN
# 8223    NaN
# 8224    NaN
# 8225    NaN
# 8226    NaN
# 8227    NaN
# 8228    NaN
# 8229    NaN
# 8230    NaN
# 8231    NaN
# 8232    NaN
# Name: end, Length: 8233, dtype: object

# %%
data.head(50)
# Out:
#          Plate       Repeat  Barcode  Measured        height   Chamber  \
# 0            1            1    14.52      27.7         27.63      39.5
# 1          NaN          NaN      NaN       NaN           NaN       NaN
# 2   Background  information      NaN       NaN           NaN       NaN
# 3        Plate        Label   Result    Signal  Flashes/Time  Meastime
# 4            1      Tatjana     FRET         0           544        10
# 5            1      Tatjana     FRET         0           554        10
# 6          NaN          NaN      NaN       NaN           NaN       NaN
# 7      Results          for  Tatjana   FRET(1)            -0   channel
# 8          NaN            1        2         3             4         5
# 9            A         1067     1097      1080           NaN       NaN
# 10           B         1034     1085      1083           NaN       NaN
# 11           C         1021     1072      1147           NaN       NaN
# 12           D         1096     1059      1051           NaN       NaN
# 13           E         1161     1087      1061           NaN       NaN
# 14           F         1080     1015      1103           NaN       NaN
# 15           G         1132     1092      1061           NaN       NaN
# 16           H         1094     1052      1028           NaN       NaN
# 17         NaN          NaN      NaN       NaN           NaN       NaN
# 18       Plate  information      NaN       NaN           NaN       NaN
# 19       Plate       Repeat  Barcode  Measured        height   Chamber
# 20           1            1    14.52      27.7         27.63      39.5
# 21         NaN          NaN      NaN       NaN           NaN       NaN
# 22  Background  information      NaN       NaN           NaN       NaN
# 23       Plate        Label   Result    Signal  Flashes/Time  Meastime
# 24           1      Tatjana     FRET         0           544        10
# 25           1      Tatjana     FRET         0           554        10
# 26         NaN          NaN      NaN       NaN           NaN       NaN
# 27     Results          for  Tatjana   FRET(1)            -0   channel
# 28         NaN            1        2         3             4         5
# 29           A        15204    15125     14188           NaN       NaN
# 30           B        12824    16080     14373           NaN       NaN
# 31           C        13898    14422     15216           NaN       NaN
# 32           D        14949    14345     15733           NaN       NaN
# 33           E        16842    16244     14599           NaN       NaN
# 34           F        17854    17006     14658           NaN       NaN
# 35           G        13272    17371     13669           NaN       NaN
# 36           H        15393    14730     14319           NaN       NaN
# 37         NaN          NaN      NaN       NaN           NaN       NaN
# 38       Plate  information      NaN       NaN           NaN       NaN
# 39       Plate       Repeat  Barcode  Measured        height   Chamber
# 40           1            2    14.52     27.63         27.63      39.6
# 41         NaN          NaN      NaN       NaN           NaN       NaN
# 42  Background  information      NaN       NaN           NaN       NaN
# 43       Plate        Label   Result    Signal  Flashes/Time  Meastime
# 44           1      Tatjana     FRET         0           544        10
# 45           1      Tatjana     FRET         0           554        10
# 46         NaN          NaN      NaN       NaN           NaN       NaN
# 47     Results          for  Tatjana   FRET(1)            -0   channel
# 48         NaN            1        2         3             4         5
# 49           A         1042      990       976           NaN       NaN
#
#      temperature      at   start Chamber.1  ...  at.5 end.2  Group  Label  \
# 0           39.6   25.46   25.48         1  ...   NaN   NaN    NaN    NaN
# 1            NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 2            NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 3       MeasInfo     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 4   00:00:00.000  De=1st  Ex=Btm    Em=Btm  ...   NaN   NaN    NaN    NaN
# 5   00:00:00.000  De=2nd  Ex=Btm    Em=Btm  ...   NaN   NaN    NaN    NaN
# 6            NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 7              1  window       1  (Counts)  ...   NaN   NaN    NaN    NaN
# 8              6       7       8         9  ...   NaN   NaN    NaN    NaN
# 9            NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 10           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 11           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 12           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 13           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 14           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 15           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 16           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 17           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 18           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 19   temperature      at   start   Chamber  ...    at   end  Group  Label
# 20          39.6   25.46   25.48         1  ...   NaN   NaN    NaN    NaN
# 21           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 22           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 23      MeasInfo     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 24  00:00:00.000  De=1st  Ex=Btm    Em=Btm  ...   NaN   NaN    NaN    NaN
# 25  00:00:00.000  De=2nd  Ex=Btm    Em=Btm  ...   NaN   NaN    NaN    NaN
# 26           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 27             2  window       1  (Counts)  ...   NaN   NaN    NaN    NaN
# 28             6       7       8         9  ...   NaN   NaN    NaN    NaN
# 29           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 30           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 31           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 32           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 33           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 34           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 35           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 36           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 37           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 38           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 39   temperature      at   start   Chamber  ...    at   end  Group  Label
# 40          39.6   25.48   25.58         1  ...   NaN   NaN    NaN    NaN
# 41           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 42           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 43      MeasInfo     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 44  00:00:00.000  De=1st  Ex=Btm    Em=Btm  ...   NaN   NaN    NaN    NaN
# 45  00:00:00.000  De=2nd  Ex=Btm    Em=Btm  ...   NaN   NaN    NaN    NaN
# 46           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
# 47             1  window       1  (Counts)  ...   NaN   NaN    NaN    NaN
# 48             6       7       8         9  ...   NaN   NaN    NaN    NaN
# 49           NaN     NaN     NaN       NaN  ...   NaN   NaN    NaN    NaN
#
#     ScanX  ScanY  Measinfo  Kinetics  Measurement  date
# 0     NaN    NaN       NaN       NaN          NaN   NaN
# 1     NaN    NaN       NaN       NaN          NaN   NaN
# 2     NaN    NaN       NaN       NaN          NaN   NaN
# 3     NaN    NaN       NaN       NaN          NaN   NaN
# 4     NaN    NaN       NaN       NaN          NaN   NaN
# 5     NaN    NaN       NaN       NaN          NaN   NaN
# 6     NaN    NaN       NaN       NaN          NaN   NaN
# 7     NaN    NaN       NaN       NaN          NaN   NaN
# 8     NaN    NaN       NaN       NaN          NaN   NaN
# 9     NaN    NaN       NaN       NaN          NaN   NaN
# 10    NaN    NaN       NaN       NaN          NaN   NaN
# 11    NaN    NaN       NaN       NaN          NaN   NaN
# 12    NaN    NaN       NaN       NaN          NaN   NaN
# 13    NaN    NaN       NaN       NaN          NaN   NaN
# 14    NaN    NaN       NaN       NaN          NaN   NaN
# 15    NaN    NaN       NaN       NaN          NaN   NaN
# 16    NaN    NaN       NaN       NaN          NaN   NaN
# 17    NaN    NaN       NaN       NaN          NaN   NaN
# 18    NaN    NaN       NaN       NaN          NaN   NaN
# 19  ScanX  ScanY  Measinfo  Kinetics  Measurement  date
# 20    NaN    NaN       NaN       NaN          NaN   NaN
# 21    NaN    NaN       NaN       NaN          NaN   NaN
# 22    NaN    NaN       NaN       NaN          NaN   NaN
# 23    NaN    NaN       NaN       NaN          NaN   NaN
# 24    NaN    NaN       NaN       NaN          NaN   NaN
# 25    NaN    NaN       NaN       NaN          NaN   NaN
# 26    NaN    NaN       NaN       NaN          NaN   NaN
# 27    NaN    NaN       NaN       NaN          NaN   NaN
# 28    NaN    NaN       NaN       NaN          NaN   NaN
# 29    NaN    NaN       NaN       NaN          NaN   NaN
# 30    NaN    NaN       NaN       NaN          NaN   NaN
# 31    NaN    NaN       NaN       NaN          NaN   NaN
# 32    NaN    NaN       NaN       NaN          NaN   NaN
# 33    NaN    NaN       NaN       NaN          NaN   NaN
# 34    NaN    NaN       NaN       NaN          NaN   NaN
# 35    NaN    NaN       NaN       NaN          NaN   NaN
# 36    NaN    NaN       NaN       NaN          NaN   NaN
# 37    NaN    NaN       NaN       NaN          NaN   NaN
# 38    NaN    NaN       NaN       NaN          NaN   NaN
# 39  ScanX  ScanY  Measinfo  Kinetics  Measurement  date
# 40    NaN    NaN       NaN       NaN          NaN   NaN
# 41    NaN    NaN       NaN       NaN          NaN   NaN
# 42    NaN    NaN       NaN       NaN          NaN   NaN
# 43    NaN    NaN       NaN       NaN          NaN   NaN
# 44    NaN    NaN       NaN       NaN          NaN   NaN
# 45    NaN    NaN       NaN       NaN          NaN   NaN
# 46    NaN    NaN       NaN       NaN          NaN   NaN
# 47    NaN    NaN       NaN       NaN          NaN   NaN
# 48    NaN    NaN       NaN       NaN          NaN   NaN
# 49    NaN    NaN       NaN       NaN          NaN   NaN
#
# [50 rows x 35 columns]
